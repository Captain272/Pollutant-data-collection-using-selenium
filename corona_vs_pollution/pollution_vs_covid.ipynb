# %%
import pandas as pd
import numpy as np

# %%
df=pd.DataFrame()

# %%
data=pd.read_csv("C:/Users/Captain/Desktop/projects/corona/data1.csv")

# %%
data.head()
# Out:
#         Date                        State       District  Confirmed  \
# 0  4/26/2020  Andaman and Nicobar Islands        Unknown         33
# 1  4/26/2020               Andhra Pradesh      Anantapur         53
# 2  4/26/2020               Andhra Pradesh       Chittoor         73
# 3  4/26/2020               Andhra Pradesh  East Godavari         39
# 4  4/26/2020               Andhra Pradesh         Guntur        214
#
#    Recovered  Deceased
# 0         11         0
# 1         14         4
# 2         13         0
# 3         12         0
# 4         29         8

# %%
da=df.values.tolist()

# %%
vals=data.values

# %%
da=vals.tolist()

# %%
da
# Out:
# [['4/26/2020', 'Andaman and Nicobar Islands', 'Unknown', 33, 11, 0],
#  ['4/26/2020', 'Andhra Pradesh', 'Anantapur', 53, 14, 4],
#  ['4/26/2020', 'Andhra Pradesh', 'Chittoor', 73, 13, 0],
#  ['4/26/2020', 'Andhra Pradesh', 'East Godavari', 39, 12, 0],
#  ['4/26/2020', 'Andhra Pradesh', 'Guntur', 214, 29, 8],
#  ['4/26/2020', 'Andhra Pradesh', 'Krishna', 177, 29, 8],
#  ['4/26/2020', 'Andhra Pradesh', 'Kurnool', 279, 31, 9],
#  ['4/26/2020', 'Andhra Pradesh', 'Prakasam', 56, 23, 0],
#  ['4/26/2020', 'Andhra Pradesh', 'S.P.S. Nellore', 72, 23, 2],
#  ['4/26/2020', 'Andhra Pradesh', 'Srikakulam', 3, 0, 0],
#  ['4/26/2020', 'Andhra Pradesh', 'Visakhapatnam', 22, 19, 0],
#  ['4/26/2020', 'Andhra Pradesh', 'West Godavari', 51, 10, 0],
#  ['4/26/2020', 'Andhra Pradesh', 'Y.S.R. Kadapa', 58, 28, 0],
#  ['4/26/2020', 'Arunachal Pradesh', 'Lohit', 1, 1, 0],
#  ['4/26/2020', 'Assam', 'Unknown', 36, 27, 1],
#  ['4/26/2020', 'Bihar', 'Arwal', 4, 0, 0],
# ...

# %%
def find(dist):
    ls=[]
    for i in da:
        if ('1/1/2021' in i):
            break
        if(dist in i):
            ls.append(i)
    return ls[5:]

# %%
l=['Meerut','Faridabad','Rohtak','Fatehgarh Sahib','Kaithal','Rupnagar','Gaya','Mumbai','Gaurela Pendra Marwahi','Chandrapur','Bengaluru Urban','Muzaffarpur']

# %% [markdown]
# Hello annaya aa top cells anni run chese badulu main retrived data:
#
# In the below data you will find A list of dictionaries each dict denotes the each district.
# inspect the below code for more.
#
# bank=[{'Date': ['5/31/2020', '6/30/2020', '7/31/2020', '8/31/2020', '9/30/2020', '10/31/2020', '11/30/2020', '12/31/2020'], 'state': ['Uttar Pradesh', 'Uttar Pradesh', 'Uttar Pradesh', 'Uttar Pradesh', 'Uttar Pradesh', 'Uttar Pradesh', 'Uttar Pradesh', 'Uttar Pradesh'], 'District': ['Meerut', 'Meerut', 'Meerut', 'Meerut', 'Meerut', 'Meerut', 'Meerut', 'Meerut'], 'Confirm': ['283.9', '688.8965517241379', '1645.6666666666665', '3019.8', '6903.0344827586205', '11884.733333333334', '16021.758620689
333333333335', '181.10344827586232', '460.0333333333335', '687.7931034482759', '918.9000000000002'], 'pollution': [35.2, 31.7, 29.8, 29.2, 31.1, 41.1, 54.7, 64.8], 'recoverd': ['0.0', '2.2758620689655182', '5.866666666666674', '30.700000000000003', '75.00000000000033', '378.0000000000001', '510.5862068965518', '669.866666666667'], 'deceased': ['0.0', '0.0', '0.0', '0.0', '0.27586206896551846', '1.6666666666666718', '7.000000000000002', '8.533333333333335']}, {'Date': ['5/31/2020', '6/30/2020', '7/31/2020', '8/31/2020', '9/30/2020', '10/31/2020', '11/30/2020', '12/31/2020'], 'state': ['Maharashtra', 'Maharashtra', 'Maharashtra', 'Maharashtra', 'Maharashtra', 'Maharashtra', 'Maharashtra', 'Maharashtra'], 'District': ['Chandrapur', 'Chandrapur', 'Chandrapur', 'Chandrapur', 'Chandrapur', 'Chandrapur', 'Chandrapur', 'Chandrapur'], 'Confirm': ['9.966666666666685', '50.37931034482766', '211.06666666666692', '1078.1000000000015', '6177.482758620697', '13410.400000000003', '18248.620689655178', '22222.4'], 'pollution': [39.1, 21.4, 20.5, 18.1, 29.2, 30.9, 40.6, 61.7], 'recoverd': ['3.3333333333333472', '33.65517241379314', '128.86666666666684', '599.3333333333338', '2818.172413793108', '9135.233333333337', '15163.068965517246', '20501.26666666667'], 'deceased': ['0.0', '0.0', '0.0', '7.0666666666666815', '62.41379310344841', '196.40000000000003', '282.2758620689656', '361.7666666666667']}, {'Date': ['5/31/2020', '6/30/2020', '7/31/2020', '8/31/2020', '9/30/2020', '10/31/2020', '11/30/2020', '12/31/2020'], 'state': ['Karnataka', 'Karnataka', 'Karnataka', 'Karnataka', 'Karnataka', 'Karnataka', 'Karnataka', 'Karnataka'], 'District': ['Bengaluru Urban', 'Bengaluru Urban', 'Bengaluru Urban', 'Bengaluru Urban', 'Bengaluru Urban', 'Bengaluru Urban', 'Bengaluru Urban', 'Bengaluru Urban'], 'Confirm': ['216.56666666666683', '1096.3793103448334', '26272.933333333367', '89772.40000000004', '178101.17241379322', '293464.0666666667', '356005.0', '379746.5333333333'], 'pollution': [22.7, 19.9, 18.4, 22.4, 21.3, 32, 27.2, 37.1], 'recoverd': ['109.60000000000015', '364.51724137931063', '6103.933333333346', '53664.96666666671', '134298.827586207', '232712.36666666676', '333077.8620689655', '362865.0'], 'deceased': ['7.700000000000002', '42.89655172413802', '495.433333333334', '1459.633333333334', '2477.827586206897', '3447.4', '4008.241379310345', '4239.233333333334']}, {'Date': ['5/31/2020', '6/30/2020', '7/31/2020', '8/31/2020', '9/30/2020', '10/31/2020', '11/30/2020', '12/31/2020'], 'state': ['Bihar', 'Bihar', 'Bihar', 'Bihar', 'Bihar', 'Bihar', 'Bihar', 'Bihar'], 'District': ['Muzaffarpur', 'Muzaffarpur', 'Muzaffarpur', 'Muzaffarpur', 'Muzaffarpur', 'Muzaffarpur', 'Muzaffarpur', 'Muzaffarpur'], 'Confirm': ['18.83333333333339', '170.20689655172436', '1014.866666666668', '4200.800000000002', '7179.689655172416', '9073.733333333334', '10308.724137931036', '11156.8'], 'pollution': [21.8, 16.6, 18, 15.1, 23, 22.5, 23.2, 38.5], 'recoverd': ['5.600000000000024', '96.34482758620713', '739.1333333333342', '3123.233333333336', '6411.275862068968', '8525.800000000001', '9974.206896551726', '10881.733333333334'], 'deceased': ['0.0', '1.310344827586208', '7.233333333333338', '20.13333333333334', '29.862068965517246', '34.50000000000001', '42.862068965517246', '45.0']}]

# %%
def built(ds):
    date=['5/31/2020','6/30/2020','7/31/2020','8/31/2020','9/30/2020','10/31/2020','11/30/2020','12/31/2020']
    days=[31,30,31,31,30,31,30,31]
    confirm=0
    recovered=0
    deseased=0
    k=0
    z=[]
    for i in ds:
        if (date[k] not in i):
#             print("came")
            confirm=confirm+i[3]
            recovered=recovered+i[4]
            deseased=deseased+i[5]
        
        if(date[k] in i):
#             print("end")
            confirm=confirm+i[3]
            recovered=recovered+i[4]
            deseased=deseased+i[5]
            i[3]=confirm/days[k]
            i[4]=recovered/days[k]
            i[5]=deseased/days[k]
            z.append(i)
            confirm=0
            recovered=0
            deseased=0
            k=k+1
#             print(i)
    return z

# %%
['5/31/2020','6/30/2020','7/31/2020','8/31/2020','9/30/2020','10/31/2020','11/30/2020','12/31/2020']
# Out:
# ['5/31/2020',
#  '6/30/2020',
#  '7/31/2020',
#  '8/31/2020',
#  '9/30/2020',
#  '10/31/2020',
#  '11/30/2020',
#  '12/31/2020']

# %%
poll=[[84.1,69,62.7,58.5,84.7,157.3,161,178.9],
           [64,69.5,56,49.9,76.8,141.3,122.6,110.9],
           [62,62.6,50,46.4,59.7,110.7,108.1,115.2],
           [68.2,55.8,66,36.6,77.3,84.3,88.4,70.9],
           [52.6,48.1,37.7,35.8,48.1,99.5,73.4,59.1],
           [52.3,42.5,32.8,36.9,47.2,65.3,59.9,56.9],
           [43.8,36.5,27.4,31.4,24.3,36.3,51.2,69.4],
           [20.6,15.9,18.6,20,24.7,42.1,63.8,70.6],
           [35.2,31.7,29.8,29.2,31.1,41.1,54.7,64.8],
           [39.1,21.4,20.5,18.1,29.2,30.9,40.6,61.7],
           [22.7,19.9,18.4,22.4,21.3,32,27.2,37.1],
           [21.8,16.6,18,15.1,23,22.5,23.2,38.5]]

# %%
def last(l):
    j=0
    for i in l:
        ds=find(i)
        kio=built(ds)
#         print(kio)
        kio=np.array(kio).T
        ka=kio.tolist()
#         ko={"Date":[],"State":[],"District":[],"Confirm":[],"recovered":[],"deceased":[]}
        ko={}
        ko["Date"]=ka[0]
        ko["state"]=ka[1]
        ko["District"]=ka[2]
        ko["Confirm"]=ka[3]
        ko["pollution"]=poll[j]
        ko["recoverd"]=ka[4]
        ko["deceased"]=ka[5]
        j=j+1
        bank.append(ko)
#         print(ka)

# %%
bank=[]
last(l)

# %%
jump=0
j=pd.DataFrame()
for i in bank:
    p=pd.DataFrame(i)
    j=j.append(p)
j.to_csv("Total"+".csv")
#     jump=jump+1

# %%
j
# Out:
#           Date          state     District             Confirm  pollution  \
# 0    5/31/2020  Uttar Pradesh       Meerut  288.83870967741933       84.1
# 1    6/30/2020  Uttar Pradesh       Meerut               699.5       69.0
# 2    7/31/2020  Uttar Pradesh       Meerut   1665.225806451613       62.7
# 3    8/31/2020  Uttar Pradesh       Meerut  3058.3548387096776       58.5
# 4    9/30/2020  Uttar Pradesh       Meerut              7001.3       84.7
# ..         ...            ...          ...                 ...        ...
# 3    8/31/2020          Bihar  Muzaffarpur   4257.290322580645       15.1
# 4    9/30/2020          Bihar  Muzaffarpur   7217.066666666667       23.0
# 5   10/31/2020          Bihar  Muzaffarpur   9096.870967741936       22.5
# 6   11/30/2020          Bihar  Muzaffarpur  10323.766666666666       23.2
# 7   12/31/2020          Bihar  Muzaffarpur   11170.90322580645       38.5
#
#               recoverd            deceased
# ...

# %%
ko={"Date":[],"State":[],"District":[],"Confirm":[],"recovered":[],"deceased":[]}

# %%
poll[0]
# Out:
# [84.1, 69, 62.7, 58.5, 84.7, 157.3, 161, 178.9]

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.figure(figsize=(8,4))       # set dimensions of the figure
Dist=['Meerut','Bulandshahi']
month=['may','june','july','aug','sep','oct','nov','dec']
# pollution =[[84.1,69,62.7,58.5,84.7,157.3,161,178.9],[85.3,65,53.6,57.4,82.2,145,150,167.1]]
# covid_Conf=[[186.017,558.406,1634.683,4123.840,7789.124,11315.854,13594.069,15233.409],[185.933,557.881,1632.902,4119.926,7784.220,11313.256,13591.637,15231.568]]
# covid_Rec=[[74.486,308.813,1034.931,3012.184,6215.225,9961.002,12665.079,14506.525],[74.398,308.466,1033.893,3008.844,6210.356,9957.820,12662.800,14504.485]]
# covid_Dec=[[5.734,17.315,40.412,78.896,127.242,172.242,199.918,221.043],[5.731,17.298,40.383,78.842,126.940,172.199,199.882,221.010]]
# j=0
# i=1
# # while j<2:
#     plt.figure(figsize=(21,12))
#     print(i)
#     plt.subplot(2,3, i)         # create subplots on a grid with 2 rows and 3 columns
#     plt.plot(month, pollution[j], covid_Conf[j])
#     plt.title('poll_Vs_Conf')
#     i=i+1
#     print(i)
#     plt.subplot(2,3, i)  
#     plt.plot(month, pollution[j], covid_Rec[j])
#     plt.title('Poll_Vs_Rec')
#     i=i+1
#     print(i)
#     plt.subplot(2,3, i)  
#     plt.plot(month, pollution[j], covid_Dec[j])
#     plt.title('Poll_Vs_Dec')
#     i=i+1
#     j=j+1
# plt.show()

# %%
bank[0]
# Out:
# {'Date': ['5/31/2020',
#   '6/30/2020',
#   '7/31/2020',
#   '8/31/2020',
#   '9/30/2020',
#   '10/31/2020',
#   '11/30/2020',
#   '12/31/2020'],
#  'state': ['Uttar Pradesh',
#   'Uttar Pradesh',
#   'Uttar Pradesh',
#   'Uttar Pradesh',
#   'Uttar Pradesh',
#   'Uttar Pradesh',
#   'Uttar Pradesh',
#   'Uttar Pradesh'],
#  'District': ['Meerut',
#   'Meerut',
#   'Meerut',
#   'Meerut',
#   'Meerut',
#   'Meerut',
#   'Meerut',
#   'Meerut'],
#  'Confirm': ['288.83870967741933',
#   '699.5',
#   '1665.225806451613',
#   '3058.3548387096776',
#   '7001.3',
#   '11940.516129032258',
#   '16116.933333333332',
#   '20724.58064516129'],
#  'pollution': [84.1, 69, 62.7, 58.5, 84.7, 157.3, 161, 178.9],
#  'recoverd': ['146.0',
#   '444.8666666666667',
#   '1173.4516129032259',
#   '2272.3225806451615',
#   '4756.566666666667',
#   '10018.193548387097',
#   '13834.7',
#   '18636.83870967742'],
#  'deceased': ['16.225806451612904',
#   '58.06666666666667',
#   '94.90322580645162',
# ...

# %%
j=1
# plt.figure(figsize=(8,4)) 
for i in bank:
    poll=[float(k) for k in i["pollution"]]
    rec=[float(k) for k in i["recoverd"]]
    dec=[float(k) for k in i["deceased"]]
    con=[float(k) for k in i["Confirm"]]
#     print(poll) #" :Pollution")
#     print(rec) #" :recovered")
#     print(dec) #" :deseased")
#     print(i["state"][0]+i["District"][0])

    plt.figure(figsize=(21,42))
    plt.subplot(10,3, j)
    plt.plot(month,poll,con,label="poll_Vs_Conf", marker='o', linestyle='--',linewidth=1)
    plt.title('poll_Vs_Conf')
    j=j+1
    plt.subplot(10,3, j)  
    plt.plot(month,poll,rec, marker='o', linestyle='--',linewidth=1)
    plt.title('Poll_Vs_Rec')
    j=j+1
#     print(i)
    plt.subplot(10,3, j)  
    plt.plot(month,poll,dec, marker='o', linestyle='--',linewidth=1)
    plt.title('Poll_Vs_Dec'+i["state"][0])
    plt.suptitle(i["state"][0]+i["District"][0],size=23)
    j=j+1
    if j>30:
        break
plt.show()
        
# pollution =[[84.1,69,62.7,58.5,84.7,157.3,161,178.9],[85.3,65,53.6,57.4,82.2,145,150,167.1]]
# covid_Conf=[[186.017,558.406,1634.683,4123.840,7789.124,11315.854,13594.069,15233.409],[185.933,557.881,1632.902,4119.926,7784.220,11313.256,13591.637,15231.568]]
# covid_Rec=[[74.486,308.813,1034.931,3012.184,6215.225,9961.002,12665.079,14506.525],[74.398,308.466,1033.893,3008.844,6210.356,9957.820,12662.800,14504.485]]
# covid_Dec=[[5.734,17.315,40.412,78.896,127.242,172.242,199.918,221.043],[5.731,17.298,40.383,78.842,126.940,172.199,199.882,221.010]]

# %%
for i in bank:
    i["pollution"]=[float(k) for k in i["pollution"]]
    i["recoverd"]=[float(k) for k in i["recoverd"]]
    i["deceased"]=[float(k) for k in i["deceased"]]
    i["Confirm"]=[float(k) for k in i["Confirm"]]

# %%
population=[3443689 ,1809733,1061204,600163,1074304 ,684627 , 4391418 , 3085411, 336420,2204307, 9621551 , 4801062]

# %%
j=1
t=0
# plt.figure(figsize=(8,4)) 
for i in bank:
    poll=[k for k in i["pollution"]]
    con=[(k/population[t])*1000 for k in i["Confirm"]]
#     c=sum(i["Confirm"])/len(i["Confirm"])
    des=[]
    rec=[]
    for m in range (8):
        de=(i["deceased"][m]/i["Confirm"][m])*100
        des.append(de)
        re=(i["recoverd"][m]/i["Confirm"][m])*100
        rec.append(re)
    
#     print(rec)

#     print(poll) #" :Pollution")
#     print(rec) #" :recovered")
#     print(dec) #" :deseased")
#     print(i["state"][0]+i["District"][0])
    
    plt.figure(figsize=(21,42))
    plt.subplot(10,4, j)
    plt.plot(month,con,label="poll_Vs_Conf", marker='o', linestyle='--',linewidth=1)
    plt.title("Cases per 1000")
    j=j+1
    plt.subplot(10,4, j)  
    plt.plot(month,rec, marker='o', linestyle='--',linewidth=1)
    plt.title("% of recovery with confirm")
    j=j+1
#     print(i)
    plt.subplot(10,4, j)  
    plt.plot(month,des, marker='o', linestyle='--',linewidth=1)
    plt.title('% Deaths with Confirmation')
    j=j+1
    plt.subplot(10,4, j)  
    plt.plot(month,poll, marker='o', linestyle='--',linewidth=1)
    plt.title('% of pollutant')
    j=j+1
    t=t+1
#     plt.suptitle(i["state"][0]+i["District"][0],size=23)
    if j>40:
        break
plt.show()
# check=[float(i) for i in bank[0]["Confirm"]]
# for i in bank[0]["Confirm"]:
#     print(((float(i))/float(population[0]))*100)
#     print(float(i))
#     print(population[0])
# check=np.array(check)
# check=check/3443689
# check
# check=check.tolist()
# check

# %%
for i in bank:
    poll=[k for k in i["pollution"]]
    con=[(k/population[t])*1000 for k in i["Confirm"]]
#     c=sum(i["Confirm"])/len(i["Confirm"])
    des=[]
    rec=[]
    for m in range (8):
        de=(i["deceased"][m]/i["Confirm"][m])*100
        des.append(de)
        re=(i["recovered"][m]/i["Confirm"][m])*100
        rec.append(re)
    
    print(des)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-26-85dc52f56718> in <module>
#       8         de=(i["deceased"][m]/i["Confirm"][m])*100
#       9         des.append(de)
# ---> 10         re=(i["recovered"][m]/i["Confirm"][m])*100
#      11         rec.append(re)
#      12
#
# KeyError: 'recovered'

# %%
# j=1
# t=0
# plt.figure(figsize=(8,4)) 
# for j in range(1):
#     poll=[k for k in i["pollution"]]
#     con=[(k/population[t])*1000 for k in i["Confirm"]]
# #     c=sum(i["Confirm"])/len(i["Confirm"])
#     des=[]
#     rec=[]
#     for m in range (8):
#         de=(i["deceased"][m]/i["Confirm"][m])*100
#         des.append(de)
#         re=(i["recoverd"][m]/i["Confirm"][m])*100
#         rec.append(re)
#     for i in bank[0]["Confirm"]:
for i in bank:
    k=i["Confirm"]
    plt.plot(month,k,label="meerut")
#         plt.plot(xs,bias_squared,'r-.',label='bais_squared')
#         plt.plot(xs,total_error,'b:',label='Total error')
#         plt.legend(loc=9)
#           print(i["Confirm"])
#           print(bank[0]["Confirm"])
    print(month)
    plt.xlabel('months')
    plt.ylabel('confirmation')
#         print(i["Confirm"])
    plt.show()
    
    
plt.figure(figsize=(21,42))
plt.show()
# Out:
# ['may', 'june', 'july', 'aug', 'sep', 'oct', 'nov', 'dec']
# ['may', 'june', 'july', 'aug', 'sep', 'oct', 'nov', 'dec']
# ['may', 'june', 'july', 'aug', 'sep', 'oct', 'nov', 'dec']
# ['may', 'june', 'july', 'aug', 'sep', 'oct', 'nov', 'dec']
# ['may', 'june', 'july', 'aug', 'sep', 'oct', 'nov', 'dec']
# ['may', 'june', 'july', 'aug', 'sep', 'oct', 'nov', 'dec']
# ['may', 'june', 'july', 'aug', 'sep', 'oct', 'nov', 'dec']
# ['may', 'june', 'july', 'aug', 'sep', 'oct', 'nov', 'dec']
# ['may', 'june', 'july', 'aug', 'sep', 'oct', 'nov', 'dec']
# ['may', 'june', 'july', 'aug', 'sep', 'oct', 'nov', 'dec']
# ['may', 'june', 'july', 'aug', 'sep', 'oct', 'nov', 'dec']
# ['may', 'june', 'july', 'aug', 'sep', 'oct', 'nov', 'dec']

# %%
plt.plot(xs,variance,'g-',label="variance")
plt.plot(xs,bias_squared,'r-.',label='bais_squared')
plt.plot(xs,total_error,'b:',label='Total error')
plt.legend(loc=9)
plt.xlabel('Model Complexity')
plt.ylabel('ALL')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-725053345098> in <module>
# ----> 1 plt.plot(xs,variance,'g-',label="variance")
#       2 plt.plot(xs,bias_squared,'r-.',label='bais_squared')
#       3 plt.plot(xs,total_error,'b:',label='Total error')
#       4 plt.legend(loc=9)
#       5 plt.xlabel('Model Complexity')
#
# NameError: name 'xs' is not defined

# %%
bank[10]["recoverd"]

# %%
# j=1
# t=0
# plt.figure(figsize=(8,4)) 
# for j in range(1):
#     poll=[k for k in i["pollution"]]
#     con=[(k/population[t])*1000 for k in i["Confirm"]]
# #     c=sum(i["Confirm"])/len(i["Confirm"])
#     des=[]
#     rec=[]
#     for m in range (8):
#         de=(i["deceased"][m]/i["Confirm"][m])*100
#         des.append(de)
#         re=(i["recoverd"][m]/i["Confirm"][m])*100
#         rec.append(re)
#     for i in bank[0]["Confirm"]:

plt.figure(figsize=(8.4,6.4))
for i in bank:
    k=i["Confirm"]
    
    plt.plot(month,k,label=i['District'][0])
#         plt.plot(xs,bias_squared,'r-.',label='bais_squared')
#         plt.plot(xs,total_error,'b:',label='Total error')
    plt.legend(loc=0)
#           print(i["Confirm"])
#           print(bank[0]["Confirm"])
#     print(month)
    plt.xlabel('months')
    plt.ylabel('confirmation')
#         print(i["Confirm"])

plt.show()

plt.figure(figsize=(8.4,6.4))
for i in bank:
#     plt.figure(figsize=(21,42))
    plt.plot(month,i['recoverd'],label=i['District'][0])
#         plt.plot(xs,bias_squared,'r-.',label='bais_squared')
#         plt.plot(xs,total_error,'b:',label='Total error')
    plt.legend(loc=0)
#           print(i["Confirm"])
#           print(bank[0]["Confirm"])
#     print(month)
    plt.xlabel('months')
    plt.ylabel('Recovered')
#         print(i["Confirm"])
plt.show()



plt.figure(figsize=(8.4,6.4))
for i in bank:
#     k=i["Confirm"]
#     plt.figure(figsize=(21,42))
    plt.plot(month,i['deceased'],label=i['District'][0])
#         plt.plot(xs,bias_squared,'r-.',label='bais_squared')
#         plt.plot(xs,total_error,'b:',label='Total error')
    plt.legend(loc=0)
#           print(i["Confirm"])
#           print(bank[0]["Confirm"])
#     print(month)
    plt.xlabel('months')
    plt.ylabel('Dead')
#         print(i["Confirm"])
plt.show()



plt.figure(figsize=(8.4,6.4))
for i in bank:
#     plt.figure(figsize=(21,42))
    plt.plot(month,i["pollution"],label=i['District'][0])
#         plt.plot(xs,bias_squared,'r-.',label='bais_squared')
#         plt.plot(xs,total_error,'b:',label='Total error')
    plt.legend(loc=0)
#           print(i["Confirm"])
#           print(bank[0]["Confirm"])
#     print(month)
    plt.xlabel('months')
    plt.ylabel('pollution')
#         print(i["Confirm"])
plt.show()
    
    

# plt.show()

# %%
# j=1
t=0
# plt.figure(figsize=(8,4)) 
# for j in range(1):
#     poll=[k for k in i["pollution"]]
#     con=[(k/population[t])*1000 for k in i["Confirm"]]
# #     c=sum(i["Confirm"])/len(i["Confirm"])
#     des=[]
#     rec=[]
#     for m in range (8):
#         de=(i["deceased"][m]/i["Confirm"][m])*100
#         des.append(de)
#         re=(i["recoverd"][m]/i["Confirm"][m])*100
#         rec.append(re)
#     for i in bank[0]["Confirm"]:

plt.figure(figsize=(8.4,6.4))
for i in bank:
    con=[(k/population[t])*1000 for k in i["Confirm"]]
    plt.plot(month,con,label=i['District'][0])
    plt.legend(loc=0)
#           print(i["Confirm"])
#           print(bank[0]["Confirm"])
#     print(month)
    plt.xlabel('months')
    plt.ylabel('rate of confirmation per 1000')
    t=t+1
#         print(i["Confirm"])

plt.show()

plt.figure(figsize=(8.4,6.4))
for i in bank:
#     plt.figure(figsize=(21,42))



#     des=[]
    rec=[]
    for m in range (8):
#         de=(i["deceased"][m]/i["Confirm"][m])*100
#         des.append(de)
        re=(i["recoverd"][m]/i["Confirm"][m])*100
        rec.append(re)
        
        

    
    plt.plot(month,rec,label=i['District'][0])
#         plt.plot(xs,bias_squared,'r-.',label='bais_squared')
#         plt.plot(xs,total_error,'b:',label='Total error')
    plt.legend(loc=0)
#           print(i["Confirm"])
#           print(bank[0]["Confirm"])
#     print(month)
    plt.xlabel('months')
    plt.ylabel('Rate of Recovered by Confirm')
#         print(i["Confirm"])
plt.show()



plt.figure(figsize=(8.4,6.4))
for i in bank:
#     k=i["Confirm"]
#     plt.figure(figsize=(21,42))

    des=[]
    for m in range (8):
        de=(i["deceased"][m]/i["Confirm"][m])*100
        des.append(de)
    
    
    plt.plot(month,des,label=i['District'][0])
#         plt.plot(xs,bias_squared,'r-.',label='bais_squared')
#         plt.plot(xs,total_error,'b:',label='Total error')
    plt.legend(loc=0)
#           print(i["Confirm"])
#           print(bank[0]["Confirm"])
#     print(month)
    plt.xlabel('months')
    plt.ylabel('Dead rate with confirmation')
#         print(i["Confirm"])
plt.show()



plt.figure(figsize=(8.4,6.4))
for i in bank:
#     plt.figure(figsize=(21,42))
    plt.plot(month,i["pollution"],label=i['District'][0])
#         plt.plot(xs,bias_squared,'r-.',label='bais_squared')
#         plt.plot(xs,total_error,'b:',label='Total error')
    plt.legend(loc=0)
#           print(i["Confirm"])
#           print(bank[0]["Confirm"])
#     print(month)
    plt.xlabel('months')
    plt.ylabel('pollution')
#         print(i["Confirm"])
plt.show()
    
    

# plt.show()
