# %%
import pandas as pd

# %%
data=pd.read_csv("C:/Users/Captain/Desktop/projects/corona_vs_pollution/data1.csv")

# %%
data['District']
# Out:
# 0                   Unknown
# 1                 Anantapur
# 2                  Chittoor
# 3             East Godavari
# 4                    Guntur
#                 ...
# 235669      Purba Bardhaman
# 235670      Purba Medinipur
# 235671              Purulia
# 235672    South 24 Parganas
# 235673       Uttar Dinajpur
# Name: District, Length: 235674, dtype: object

# %%
dist=[i for i in data['District']]
state=[i for i in data['State']]

# %%
both=zip(dist,state)
both2=zip(state,dist)

# %%
both=list(both)
both
# Out:
# [('Agar Malwa', 'Madhya Pradesh'),
#  ('Agra', 'Uttar Pradesh'),
#  ('Ahmedabad', 'Gujarat'),
#  ('Ahmednagar', 'Maharashtra'),
#  ('Airport Quarantine', 'Tamil Nadu'),
#  ('Aizawl', 'Mizoram'),
#  ('Ajmer', 'Rajasthan'),
#  ('Akola', 'Maharashtra'),
#  ('Alappuzha', 'Kerala'),
#  ('Aligarh', 'Uttar Pradesh'),
#  ('Alipurduar', 'West Bengal'),
#  ('Alirajpur', 'Madhya Pradesh'),
#  ('Almora', 'Uttarakhand'),
#  ('Alwar', 'Rajasthan'),
#  ('Ambala', 'Haryana'),
#  ('Ambedkar Nagar', 'Uttar Pradesh'),
#  ('Amethi', 'Uttar Pradesh'),
#  ('Amravati', 'Maharashtra'),
#  ('Amreli', 'Gujarat'),
#  ('Amritsar', 'Punjab'),
#  ('Amroha', 'Uttar Pradesh'),
#  ('Anand', 'Gujarat'),
#  ('Anantapur', 'Andhra Pradesh'),
#  ('Anantnag', 'Jammu and Kashmir'),
#  ('Angul', 'Odisha'),
#  ('Anjaw', 'Arunachal Pradesh'),
#  ('Anuppur', 'Madhya Pradesh'),
#  ('Araria', 'Bihar'),
#  ('Aravalli', 'Gujarat'),
#  ('Ariyalur', 'Tamil Nadu'),
#  ('Arwal', 'Bihar'),
#  ('Ashoknagar', 'Madhya Pradesh'),
# ...

# %%
both.sort()
both2.sort()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-33-0af40bdb13c3> in <module>
#       1 both.sort()
# ----> 2 both2.sort()
#
# AttributeError: 'zip' object has no attribute 'sort'

# %%
both=set(both)
both2=set(both2)

# %%
both=list(both)
both.sort()
both2=list(both2)
both2.sort()
both2
# Out:
# [('Andaman and Nicobar Islands', 'Unknown'),
#  ('Andhra Pradesh', 'Anantapur'),
#  ('Andhra Pradesh', 'Chittoor'),
#  ('Andhra Pradesh', 'East Godavari'),
#  ('Andhra Pradesh', 'Foreign Evacuees'),
#  ('Andhra Pradesh', 'Guntur'),
#  ('Andhra Pradesh', 'Krishna'),
#  ('Andhra Pradesh', 'Kurnool'),
#  ('Andhra Pradesh', 'Other State'),
#  ('Andhra Pradesh', 'Prakasam'),
#  ('Andhra Pradesh', 'S.P.S. Nellore'),
#  ('Andhra Pradesh', 'Srikakulam'),
#  ('Andhra Pradesh', 'Unknown'),
#  ('Andhra Pradesh', 'Visakhapatnam'),
#  ('Andhra Pradesh', 'Vizianagaram'),
#  ('Andhra Pradesh', 'West Godavari'),
#  ('Andhra Pradesh', 'Y.S.R. Kadapa'),
#  ('Arunachal Pradesh', 'Anjaw'),
#  ('Arunachal Pradesh', 'Capital Complex'),
#  ('Arunachal Pradesh', 'Changlang'),
#  ('Arunachal Pradesh', 'East Kameng'),
#  ('Arunachal Pradesh', 'East Siang'),
#  ('Arunachal Pradesh', 'Kamle'),
#  ('Arunachal Pradesh', 'Kra Daadi'),
#  ('Arunachal Pradesh', 'Kurung Kumey'),
# ...

# %%
dist.sort()

# %%
perfect=set(dist)

# %%
perfect=list
# Out:
# {'Agar Malwa',
#  'Agra',
#  'Ahmedabad',
#  'Ahmednagar',
#  'Airport Quarantine',
#  'Aizawl',
#  'Ajmer',
#  'Akola',
#  'Alappuzha',
#  'Aligarh',
#  'Alipurduar',
#  'Alirajpur',
#  'Almora',
#  'Alwar',
#  'Ambala',
#  'Ambedkar Nagar',
#  'Amethi',
#  'Amravati',
#  'Amreli',
#  'Amritsar',
#  'Amroha',
#  'Anand',
#  'Anantapur',
#  'Anantnag',
#  'Angul',
#  'Anjaw',
#  'Anuppur',
#  'Araria',
#  'Aravalli',
#  'Ariyalur',
#  'Arwal',
#  'Ashoknagar',
#  'Auraiya',
#  'Aurangabad',
#  'Ayodhya',
#  'Azamgarh',
#  'BSF Camp',
#  'Bagalkote',
#  'Bageshwar',
#  'Baghpat',
#  'Bahraich',
#  'Balaghat',
#  'Balangir',
#  'Balasore',
#  'Ballari',
#  'Ballia',
#  'Balod',
#  'Baloda Bazar',
#  'Balrampur',
#  'Bametara',
#  'Banaskantha',
#  'Banda',
#  'Bandipora',
#  'Banka',
#  'Bankura',
#  'Banswara',
#  'Barabanki',
#  'Baramulla',
#  'Baran',
#  'Bareilly',
#  'Bargarh',
#  'Barmer',
#  'Barnala',
#  'Barwani',
#  'Bastar',
#  'Basti',
#  'Bathinda',
#  'Beed',
# ...
